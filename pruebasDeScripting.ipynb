# %% [markdown]
# <a href="https://colab.research.google.com/github/joluva/datascience/blob/main/pruebasDeScripting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x=[2,3,4,5]
nums=np.array(x)
print(nums*2)

print(nums/(np.max(nums)))
# Out:
# [ 4  6  8 10]
# [0.4 0.6 0.8 1. ]

# %%
import requests
import json
import json.dump
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1498973673.py in <cell line: 0>()
#       1 import requests
#       2 import json
# ----> 3 import json.dump
#
# ModuleNotFoundError: No module named 'json.dump'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
a=[1,2,3,4]
b=[1,3,6,7]

c=a*2

print(c)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
response=requests.get("https://api.github.com")
print(response.status_code)
# Out:
# 200

# %%
url="https://sv443.net/jokeapi/v2/joke/Pun?type=twopart"

joke=requests.get(url)
print(json_dumps(joke,indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3197549628.py in <cell line: 0>()
#       2
#       3 joke=requests.get(url)
# ----> 4 print(json_dumps(joke,indent=2))
#
# NameError: name 'json_dumps' is not defined
